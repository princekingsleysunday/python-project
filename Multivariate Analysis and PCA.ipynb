# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('USA_cars_datasets (1).csv')

# %%
data
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# ...

# %%
data.drop('Unnamed: 0', axis =1, inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

# %%
data['color'] = encoder.fit_transform(data['color'])
data['brand'] = encoder.fit_transform(data['brand'])
data['model'] = encoder.fit_transform(data['model'])

# %%
# extract the features(independednt variable) and labels (dependent variable)

# value is a keyword to convert the df to an array
x = data.loc[:,['lot','brand','color','model','year']].values
y= data.iloc[:,0].values

# %% [markdown]
# # PCA

# %%
# step 1: standardizing the features
# assuming the dataset follows a normal distribution

from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_scaled = sc.fit_transform(x)

# %%
x_scaled
# Out:
# array([[-40.92787873,   2.93072775,  -1.30994535,  -0.84326433,
#          -2.5317747 ],
#        [ -3.63098547,  -0.29737637,   0.75835056,   1.33452252,
#          -1.66018013],
#        [ -0.17494941,  -0.46727659,   0.75835056,   0.78194974,
#           0.37354053],
#        ...,
#        [  0.34751857,   2.4210271 ,   0.75835056,   2.2446424 ,
#           0.37354053],
#        [  0.34752348,   2.4210271 ,  -1.30994535,   2.2446424 ,
#           0.37354053],
#        [  0.34752838,   2.4210271 ,   0.75835056,   2.2446424 ,
#           0.37354053]])

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 4)

p = pca.fit_transform(x_scaled)

# %%
p
# Out:
# array([[12.57176871, 29.25805577, 10.57375874, 18.72027854],
#        [ 0.99332876,  2.73825089,  2.46690916,  0.13267633],
#        [ 0.15678731, -0.63715432,  0.8037917 ,  0.05420219],
#        ...,
#        [ 2.83095652, -0.98447439,  1.09720619, -0.86658925],
#        [ 3.21004258, -0.31916391, -0.72830485, -1.30551309],
#        [ 2.83095375, -0.98448078,  1.09720351, -0.86659407]])

# %%
principalDF = pd.DataFrame(data=p, columns= ['PC1', 'PC2', 'PC3', 'PC4'])
finalDf = pd.concat([principalDF, data[['price']]], axis = 1)
finalDf.head()
# Out:
#          PC1        PC2        PC3        PC4  price
# 0  12.571769  29.258056  10.573759  18.720279   6300
# 1   0.993329   2.738251   2.466909   0.132676   2899
# 2   0.156787  -0.637154   0.803792   0.054202   5350
# 3  -0.654083   0.799467  -1.083532  -0.603093  25000
# 4  -1.600130  -0.271212  -0.222382   1.024662  27700
